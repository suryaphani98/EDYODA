# %%
import pandas as pd
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn import preprocessing
import numpy as np
from sklearn.linear_model import LinearRegression, Lasso
import datetime
from statistics import mean

# %%
data= pd.read_csv('weatherHistory.csv')

# %%
data["Date"]=pd.to_datetime(data["Formatted Date"],utc=True)
data["Month"]=data["Date"].dt.month
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 12295  2007-01-05 07:00:00.000 +0100       Overcast        rain
# 12296  2007-01-05 08:00:00.000 +0100  Partly Cloudy        rain
# 12297  2007-01-05 09:00:00.000 +0100          Clear        rain
# 12298  2007-01-05 10:00:00.000 +0100  Partly Cloudy        rain
# 12299  2007-01-05 11:00:00.000 +0100  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# 1             9.355556                  7.227778      0.86            14.2646
# 2             9.377778                  9.377778      0.89             3.9284
# 3             8.288889                  5.944444      0.83            14.1036
# 4             8.755556                  6.977778      0.83            11.0446
# ...                ...                       ...       ...                ...
# 12295         2.466667                 -0.122222      0.99             9.0965
# 12296         2.316667                 -0.377778      0.99             9.3863
# 12297         2.966667                  0.905556      0.99             7.5187
# 12298         5.927778                  3.522222      0.87            11.3344
# 12299         8.772222                  6.500000      0.77            14.3612
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                       251.0          15.8263         0.0
# 1                       259.0          15.8263         0.0
# 2                       204.0          14.9569         0.0
# 3                       269.0          15.8263         0.0
# 4                       259.0          15.8263         0.0
# ...                       ...              ...         ...
# 12295                   202.0           5.5384         0.0
# 12296                   204.0           4.2987         0.0
# 12297                   177.0           4.7495         0.0
# 12298                   243.0           9.6278         0.0
# 12299                   251.0           9.9820         0.0
#
#        Pressure (millibars)                      Daily Summary  \
# 0                   1015.13  Partly cloudy throughout the day.
# 1                   1015.63  Partly cloudy throughout the day.
# 2                   1015.94  Partly cloudy throughout the day.
# 3                   1016.41  Partly cloudy throughout the day.
# 4                   1016.51  Partly cloudy throughout the day.
# ...                     ...                                ...
# 12295               1018.42         Mostly cloudy until night.
# 12296               1018.41         Mostly cloudy until night.
# 12297               1019.08         Mostly cloudy until night.
# 12298               1019.53         Mostly cloudy until night.
# 12299                 10.00                                NaN
#
#                            Date  Month
# 0     2006-03-31 22:00:00+00:00      3
# 1     2006-03-31 23:00:00+00:00      3
# 2     2006-04-01 00:00:00+00:00      4
# 3     2006-04-01 01:00:00+00:00      4
# 4     2006-04-01 02:00:00+00:00      4
# ...                         ...    ...
# 12295 2007-01-05 06:00:00+00:00      1
# 12296 2007-01-05 07:00:00+00:00      1
# 12297 2007-01-05 08:00:00+00:00      1
# 12298 2007-01-05 09:00:00+00:00      1
# 12299 2007-01-05 10:00:00+00:00      1
#
# [12300 rows x 14 columns]

# %%
data = data.drop(["Formatted Date","Daily Summary","Pressure (millibars)","Wind Speed (km/h)","Humidity","Loud Cover","Date"],axis=1)
data
# Out:
#              Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0      Partly Cloudy        rain         9.472222                  7.388889
# 1      Partly Cloudy        rain         9.355556                  7.227778
# 2      Mostly Cloudy        rain         9.377778                  9.377778
# 3      Partly Cloudy        rain         8.288889                  5.944444
# 4      Mostly Cloudy        rain         8.755556                  6.977778
# ...              ...         ...              ...                       ...
# 12295       Overcast        rain         2.466667                 -0.122222
# 12296  Partly Cloudy        rain         2.316667                 -0.377778
# 12297          Clear        rain         2.966667                  0.905556
# 12298  Partly Cloudy        rain         5.927778                  3.522222
# 12299  Partly Cloudy        rain         8.772222                  6.500000
#
#        Wind Bearing (degrees)  Visibility (km)  Month
# 0                       251.0          15.8263      3
# 1                       259.0          15.8263      3
# 2                       204.0          14.9569      4
# 3                       269.0          15.8263      4
# 4                       259.0          15.8263      4
# ...                       ...              ...    ...
# 12295                   202.0           5.5384      1
# 12296                   204.0           4.2987      1
# 12297                   177.0           4.7495      1
# 12298                   243.0           9.6278      1
# 12299                   251.0           9.9820      1
#
# [12300 rows x 7 columns]

# %%
label_encoder = preprocessing.LabelEncoder()
data["Summary"]=label_encoder.fit_transform(data["Summary"])
data["Summary"].unique()
data
# Out:
#        Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0           13        rain         9.472222                  7.388889
# 1           13        rain         9.355556                  7.227778
# 2           11        rain         9.377778                  9.377778
# 3           13        rain         8.288889                  5.944444
# 4           11        rain         8.755556                  6.977778
# ...        ...         ...              ...                       ...
# 12295       12        rain         2.466667                 -0.122222
# 12296       13        rain         2.316667                 -0.377778
# 12297        5        rain         2.966667                  0.905556
# 12298       13        rain         5.927778                  3.522222
# 12299       13        rain         8.772222                  6.500000
#
#        Wind Bearing (degrees)  Visibility (km)  Month
# 0                       251.0          15.8263      3
# 1                       259.0          15.8263      3
# 2                       204.0          14.9569      4
# 3                       269.0          15.8263      4
# 4                       259.0          15.8263      4
# ...                       ...              ...    ...
# 12295                   202.0           5.5384      1
# 12296                   204.0           4.2987      1
# 12297                   177.0           4.7495      1
# 12298                   243.0           9.6278      1
# 12299                   251.0           9.9820      1
#
# [12300 rows x 7 columns]

# %%
data["Precip Type"]=data["Precip Type"].replace(["rain","snow"],[0,1])
data
# Out:
#        Summary  Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0           13            0         9.472222                  7.388889
# 1           13            0         9.355556                  7.227778
# 2           11            0         9.377778                  9.377778
# 3           13            0         8.288889                  5.944444
# 4           11            0         8.755556                  6.977778
# ...        ...          ...              ...                       ...
# 12295       12            0         2.466667                 -0.122222
# 12296       13            0         2.316667                 -0.377778
# 12297        5            0         2.966667                  0.905556
# 12298       13            0         5.927778                  3.522222
# 12299       13            0         8.772222                  6.500000
#
#        Wind Bearing (degrees)  Visibility (km)  Month
# 0                       251.0          15.8263      3
# 1                       259.0          15.8263      3
# 2                       204.0          14.9569      4
# 3                       269.0          15.8263      4
# 4                       259.0          15.8263      4
# ...                       ...              ...    ...
# 12295                   202.0           5.5384      1
# 12296                   204.0           4.2987      1
# 12297                   177.0           4.7495      1
# 12298                   243.0           9.6278      1
# 12299                   251.0           9.9820      1
#
# [12300 rows x 7 columns]

# %%
data.isna().sum()
# Out:
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Month                       0
# dtype: int64

# %%
data["Precip Type"]=data["Precip Type"].replace(np.nan,0)
data.isna().sum()
# Out:
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Month                       0
# dtype: int64

# %%
y=data["Apparent Temperature (C)"]
data = data.drop("Apparent Temperature (C)",axis =1)
print(data)
# Out:
#        Summary  Precip Type  Temperature (C)  Wind Bearing (degrees)  \
# 0           13            0         9.472222                   251.0
# 1           13            0         9.355556                   259.0
# 2           11            0         9.377778                   204.0
# 3           13            0         8.288889                   269.0
# 4           11            0         8.755556                   259.0
# ...        ...          ...              ...                     ...
# 12295       12            0         2.466667                   202.0
# 12296       13            0         2.316667                   204.0
# 12297        5            0         2.966667                   177.0
# 12298       13            0         5.927778                   243.0
# 12299       13            0         8.772222                   251.0
#
#        Visibility (km)  Month
# 0              15.8263      3
# 1              15.8263      3
# 2              14.9569      4
# 3              15.8263      4
# 4              15.8263      4
# ...                ...    ...
# 12295           5.5384      1
# 12296           4.2987      1
# 12297           4.7495      1
# 12298           9.6278      1
# 12299           9.9820      1
#
# [12300 rows x 6 columns]

# %%
y
# Out:
# 0        7.388889
# 1        7.227778
# 2        9.377778
# 3        5.944444
# 4        6.977778
#            ...
# 12295   -0.122222
# 12296   -0.377778
# 12297    0.905556
# 12298    3.522222
# 12299    6.500000
# Name: Apparent Temperature (C), Length: 12300, dtype: float64

# %%
X_train, X_test,y_train,y_test=train_test_split(data,y,test_size=0.2,random_state=0)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_test)

# %%
#finding variance using np
Variance = np.var(pred)
Variance
# Out:
# 116.5238922764958

# %%
SSE = np.mean((np.mean(pred)-y)**2)
Bias = SSE-Variance
Bias
# Out:
# 2.3530095168597
